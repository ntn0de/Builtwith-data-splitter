# %%
import pandas as pd

# %%
mydata0 = pd.read_csv("US-Woocomm.csv")

# %%
print(mydata0)
# Out:
#                            Domain  \
# 0                   2checkout.com
# 1                       b-cdn.net
# 2                   backblaze.com
# 3                    banimode.com
# 4                   barcelona.cat
# ...                           ...
# 3023607              tokyojoes.tv
# 3023608         tokyolectures.org
# 3023609          tokyoonthego.com
# 3023610  tokyoorganicmalaysia.com
# 3023611        tokyothaisushi.com
#
#                                           Location on Site Tech Spend USD  \
# 0          2checkout.com/*;knowledgecenter.2checkout.com/*          $5000
# 1        8milesfromhome.b-cdn.net;firstaltcoop.b-cdn.ne...          $5000
# 2                                            backblaze.com         $10000
# 3                     blog.banimode.com;b2b.banimode.com/*          $1000
# 4        ajuntament.barcelona.cat/*;lameva.barcelona.ca...          $2000
# ...                                                    ...            ...
# 3023607                                       tokyojoes.tv             $0
# 3023608                                  tokyolectures.org             $0
# 3023609                                   tokyoonthego.com            $10
# 3023610                           tokyoorganicmalaysia.com             $0
# 3023611                                 tokyothaisushi.com             $0
#
#         Sales Revenue USD                  Company                  Vertical  \
# 0                $2780875                2Checkout   Business And Industrial
# 1                     NaN                      NaN                       NaN
# 2                $1008369            Backblaze Inc  Technology And Computing
# 3                     NaN                      NaN     Art And Entertainment
# 4                     NaN  AJUNTAMENT DE BARCELONA                   Science
# ...                   ...                      ...                       ...
# 3023607               NaN                      NaN                       NaN
# 3023608               NaN                      NaN                       NaN
# 3023609              $400                      NaN                       NaN
# 3023610               NaN                      NaN   Business And Industrial
# 3023611               NaN                      NaN                       NaN
#
#                  Tranco         Page Rank        Majestic        Umbrella  \
# 0                 14360              7352            6611           28103
# 1                477649              9178           10471            1135
# 2                  9793              4995            7262            6338
# 3                290835            147161  Outside Top 1m  Outside Top 1m
# 4                 41265             14705            5206  Outside Top 1m
# ...                 ...               ...             ...             ...
# 3023607  Outside Top 1m  Outside Top 100m  Outside Top 1m  Outside Top 1m
# 3023608  Outside Top 1m          16130178  Outside Top 1m  Outside Top 1m
# 3023609  Outside Top 1m  Outside Top 100m  Outside Top 1m  Outside Top 1m
# 3023610  Outside Top 1m          85229667  Outside Top 1m  Outside Top 1m
# 3023611  Outside Top 1m          22730594  Outside Top 1m  Outside Top 1m
#
#          ...        City State      Zip Country First Detected  Last Found  \
# 0        ...  Alpharetta    GA    30022      US     2016-06-16  2021-03-01
# 1        ...         NaN   NaN      NaN     NaN     2021-01-16  2021-06-12
# 2        ...   San Mateo    CA    94401      US     2017-10-05  2021-07-25
# 3        ...         NaN   NaN      NaN     NaN     2016-11-15  2021-07-20
# 4        ...   Barcelona    CT    08002      ES     2016-11-22  2021-07-31
# ...      ...         ...   ...      ...     ...            ...         ...
# 3023607  ...    Hooksett    NH   3106.0      US     2020-04-02  2021-07-30
# 3023608  ...         NaN   NaN      NaN     NaN     2020-02-25  2021-07-30
# 3023609  ...         NaN   NaN      NaN     NaN     2021-04-05  2021-04-05
# 3023610  ...         NaN   NaN      NaN     NaN     2018-05-02  2021-07-30
# 3023611  ...      Naples    FL  34112.0      US     2020-06-29  2021-07-30
#
#         First Indexed Last Indexed Exclusion       Compliance
# 0          2011-01-03   2021-08-01         -                -
# 1          2016-04-25   2021-07-31         -                -
# 2          2011-04-03   2021-08-01         -  California CCPA
# 3          2015-06-02   2021-07-27         -                -
# 4          2012-04-05   2021-08-01         -       GDPR Spain
# ...               ...          ...       ...              ...
# 3023607    2020-04-02   2021-07-30         -                -
# 3023608    2017-10-16   2021-07-30         -                -
# 3023609    2020-11-26   2021-07-30         -                -
# 3023610    2018-05-02   2021-07-30         -                -
# 3023611    2018-06-11   2021-07-30         -                -
#
# [3023612 rows x 34 columns]

# %%
 
# creating a list of column names by
# calling the .columns
list_of_column_names = list(mydata0.columns)
 
# displaying the list of column names
print('List of column names : ',
      list_of_column_names)
# Out:
# List of column names :  ['Domain', 'Location on Site', 'Tech Spend USD', 'Sales Revenue USD', 'Company', 'Vertical', 'Tranco', 'Page Rank', 'Majestic', 'Umbrella', 'Telephones', 'Emails', 'Twitter', 'Facebook', 'LinkedIn', 'Google', 'Pinterest', 'GitHub', 'Instagram', 'Vk', 'Vimeo', 'Youtube', 'TikTok', 'People', 'City', 'State', 'Zip', 'Country', 'First Detected', 'Last Found', 'First Indexed', 'Last Indexed', 'Exclusion', 'Compliance']

# %%
#sorting
a = mydata0['Vertical'].unique()
print(a)
print(len(a))
# Out:
# ['Finance' 'Education' 'Law  Govt And Politics' 'Art And Entertainment'
#  'Sports' 'Business And Industrial' nan 'Technology And Computing'
#  'Style And Fashion' 'Society' 'Health And Fitness' 'Science' 'Travel'
#  'Real Estate' 'Automotive And Vehicles' 'Shopping' 'Family And Parenting'
#  'Home And Garden' 'Food And Drink' 'Careers' 'Hobbies And Interests'
#  'Religion And Spirituality' 'Pets' 'News' 'Adult']
# 25

# %%
allver= mydata0['Vertical'].value_counts();
print(allver)
total_ver = len(mydata0['Vertical'].value_counts())
print('total: ',total_ver)
# Out:
# Art And Entertainment        252915
# Business And Industrial      191853
# Food And Drink                61168
# Health And Fitness            54173
# Technology And Computing      54024
# Education                     47690
# Style And Fashion             46140
# Travel                        34202
# Hobbies And Interests         31485
# Home And Garden               30363
# Finance                       28817
# Sports                        27106
# Science                       26206
# Law  Govt And Politics        22012
# Society                       22006
# Automotive And Vehicles       20039
# Real Estate                   16737
# Careers                       10574
# Shopping                       9329
# Family And Parenting           8969
# Pets                           5343
# Religion And Spirituality      1281
# Adult                           945
# News                             19
# Name: Vertical, dtype: int64
# total:  24

# %%
import numpy as np
print('from' ,a)
for x in a:
    if(pd.isna(x) == 0):
        print('trying : ',x )
        print(x+'.csv')
        newval = mydata0[mydata0['Vertical'] == x].to_csv(x+'.csv')
        #csv file name to be read in
        in_csv = x+'.csv'

        #get the number of lines of the csv file to be read
        number_lines = sum(1 for row in (open(in_csv)))

        #size of rows of data to write to the csv,

        #you can change the row size according to your need
        rowsize = 5000

        #start looping through data writing it to a new file for each set
        for i in range(0,number_lines,rowsize):

            newdf = pd.read_csv(in_csv,
                  nrows = rowsize,#number of rows to read at each loop
                  skiprows = i)#skip rows that have been read

            #csv to write data to a new file with indexed name. input_1.csv etc.
            out_csv = x + str(i) + '.csv'

            newdf.to_csv(out_csv,
                  index=True,
                  header=False,
                  mode='a',#append data to csv file
                  chunksize=rowsize)#size of data to append for each l
        print('saved')
# Out:
# from ['Finance' 'Education' 'Law  Govt And Politics' 'Art And Entertainment'
#  'Sports' 'Business And Industrial' nan 'Technology And Computing'
#  'Style And Fashion' 'Society' 'Health And Fitness' 'Science' 'Travel'
#  'Real Estate' 'Automotive And Vehicles' 'Shopping' 'Family And Parenting'
#  'Home And Garden' 'Food And Drink' 'Careers' 'Hobbies And Interests'
#  'Religion And Spirituality' 'Pets' 'News' 'Adult']
# trying :  Finance
# Finance.csv
# saved
# trying :  Education
# Education.csv
# saved
# trying :  Law  Govt And Politics
# Law  Govt And Politics.csv
# saved
# trying :  Art And Entertainment
# Art And Entertainment.csv
# saved
# trying :  Sports
# Sports.csv
# saved
# trying :  Business And Industrial
# Business And Industrial.csv
# saved
# trying :  Technology And Computing
# Technology And Computing.csv
# saved
# trying :  Style And Fashion
# Style And Fashion.csv
# saved
# trying :  Society
# Society.csv
# saved
# trying :  Health And Fitness
# Health And Fitness.csv
# saved
# trying :  Science
# Science.csv
# saved
# trying :  Travel
# Travel.csv
# saved
# trying :  Real Estate
# Real Estate.csv
# saved
# trying :  Automotive And Vehicles
# Automotive And Vehicles.csv
# saved
# trying :  Shopping
# Shopping.csv
# saved
# trying :  Family And Parenting
# Family And Parenting.csv
# saved
# trying :  Home And Garden
# Home And Garden.csv
# saved
# trying :  Food And Drink
# Food And Drink.csv
# saved
# trying :  Careers
# Careers.csv
# saved
# trying :  Hobbies And Interests
# Hobbies And Interests.csv
# saved
# trying :  Religion And Spirituality
# Religion And Spirituality.csv
# saved
# trying :  Pets
# Pets.csv
# saved
# trying :  News
# News.csv
# saved
# trying :  Adult
# Adult.csv
# saved

# %%
import numpy as np
import csv
import sys
import os
print('from' ,a)
for x in a:
    if(pd.isna(x) == 0):
        print('trying : ',x )
        print(x+'.csv')
        newval = mydata0[mydata0['Vertical'] == x].to_csv(x+'.csv')
        filename = x+'.csv'

        rows_per_csv = 5000

        with open(filename) as infile:
            reader = csv.DictReader(infile)
            header = reader.fieldnames
            rows = [row for row in reader]
            pages = []

            row_count = len(rows)
            start_index = 0
            # here, we slice the total rows into pages, each page having [row_per_csv] rows
            while start_index < row_count:
                pages.append(rows[start_index: start_index+rows_per_csv])
                start_index += rows_per_csv

            for i, page in enumerate(pages):
                with open('{}_{}.csv'.format(x, i+1), 'w+') as outfile:
                    writer = csv.DictWriter(outfile, fieldnames=header)
                    writer.writeheader()
                    for row in page:
                        writer.writerow(row)

                print('DONE splitting {} into {} files'.format(x, len(pages)))
        print('saved')
        os.remove(x+'.csv')
# Out:
# from ['Finance' 'Education' 'Law  Govt And Politics' 'Art And Entertainment'
#  'Sports' 'Business And Industrial' nan 'Technology And Computing'
#  'Style And Fashion' 'Society' 'Health And Fitness' 'Science' 'Travel'
#  'Real Estate' 'Automotive And Vehicles' 'Shopping' 'Family And Parenting'
#  'Home And Garden' 'Food And Drink' 'Careers' 'Hobbies And Interests'
#  'Religion And Spirituality' 'Pets' 'News' 'Adult']
# trying :  Finance
# Finance.csv
# DONE splitting Finance into 6 files
# DONE splitting Finance into 6 files
# DONE splitting Finance into 6 files
# DONE splitting Finance into 6 files
# DONE splitting Finance into 6 files
# DONE splitting Finance into 6 files
# saved
# trying :  Education
# Education.csv
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# DONE splitting Education into 10 files
# saved
# trying :  Law  Govt And Politics
# Law  Govt And Politics.csv
# DONE splitting Law  Govt And Politics into 5 files
# DONE splitting Law  Govt And Politics into 5 files
# DONE splitting Law  Govt And Politics into 5 files
# DONE splitting Law  Govt And Politics into 5 files
# DONE splitting Law  Govt And Politics into 5 files
# saved
# trying :  Art And Entertainment
# Art And Entertainment.csv
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# DONE splitting Art And Entertainment into 51 files
# saved
# trying :  Sports
# Sports.csv
# DONE splitting Sports into 6 files
# DONE splitting Sports into 6 files
# DONE splitting Sports into 6 files
# DONE splitting Sports into 6 files
# DONE splitting Sports into 6 files
# DONE splitting Sports into 6 files
# saved
# trying :  Business And Industrial
# Business And Industrial.csv
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# DONE splitting Business And Industrial into 39 files
# saved
# trying :  Technology And Computing
# Technology And Computing.csv
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# DONE splitting Technology And Computing into 11 files
# saved
# trying :  Style And Fashion
# Style And Fashion.csv
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# DONE splitting Style And Fashion into 10 files
# saved
# trying :  Society
# Society.csv
# DONE splitting Society into 5 files
# DONE splitting Society into 5 files
# DONE splitting Society into 5 files
# DONE splitting Society into 5 files
# DONE splitting Society into 5 files
# saved
# trying :  Health And Fitness
# Health And Fitness.csv
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# DONE splitting Health And Fitness into 11 files
# saved
# trying :  Science
# Science.csv
# DONE splitting Science into 6 files
# DONE splitting Science into 6 files
# DONE splitting Science into 6 files
# DONE splitting Science into 6 files
# DONE splitting Science into 6 files
# DONE splitting Science into 6 files
# saved
# trying :  Travel
# Travel.csv
# DONE splitting Travel into 7 files
# DONE splitting Travel into 7 files
# DONE splitting Travel into 7 files
# DONE splitting Travel into 7 files
# DONE splitting Travel into 7 files
# DONE splitting Travel into 7 files
# DONE splitting Travel into 7 files
# saved
# trying :  Real Estate
# Real Estate.csv
# DONE splitting Real Estate into 4 files
# DONE splitting Real Estate into 4 files
# DONE splitting Real Estate into 4 files
# DONE splitting Real Estate into 4 files
# saved
# trying :  Automotive And Vehicles
# Automotive And Vehicles.csv
# DONE splitting Automotive And Vehicles into 5 files
# DONE splitting Automotive And Vehicles into 5 files
# DONE splitting Automotive And Vehicles into 5 files
# DONE splitting Automotive And Vehicles into 5 files
# DONE splitting Automotive And Vehicles into 5 files
# saved
# trying :  Shopping
# Shopping.csv
# DONE splitting Shopping into 2 files
# DONE splitting Shopping into 2 files
# saved
# trying :  Family And Parenting
# Family And Parenting.csv
# DONE splitting Family And Parenting into 2 files
# DONE splitting Family And Parenting into 2 files
# saved
# trying :  Home And Garden
# Home And Garden.csv
# DONE splitting Home And Garden into 7 files
# DONE splitting Home And Garden into 7 files
# DONE splitting Home And Garden into 7 files
# DONE splitting Home And Garden into 7 files
# DONE splitting Home And Garden into 7 files
# DONE splitting Home And Garden into 7 files
# DONE splitting Home And Garden into 7 files
# saved
# trying :  Food And Drink
# Food And Drink.csv
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# DONE splitting Food And Drink into 13 files
# saved
# trying :  Careers
# Careers.csv
# DONE splitting Careers into 3 files
# DONE splitting Careers into 3 files
# DONE splitting Careers into 3 files
# saved
# trying :  Hobbies And Interests
# Hobbies And Interests.csv
# DONE splitting Hobbies And Interests into 7 files
# DONE splitting Hobbies And Interests into 7 files
# DONE splitting Hobbies And Interests into 7 files
# DONE splitting Hobbies And Interests into 7 files
# DONE splitting Hobbies And Interests into 7 files
# DONE splitting Hobbies And Interests into 7 files
# DONE splitting Hobbies And Interests into 7 files
# saved
# trying :  Religion And Spirituality
# Religion And Spirituality.csv
# DONE splitting Religion And Spirituality into 1 files
# saved
# trying :  Pets
# Pets.csv
# DONE splitting Pets into 2 files
# DONE splitting Pets into 2 files
# saved
# trying :  News
# News.csv
# DONE splitting News into 1 files
# saved
# trying :  Adult
# Adult.csv
# DONE splitting Adult into 1 files
# saved
